# %%
# %matplotlib inline
import os
import cv2
import time
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from weapons.Se_0a import seg_model
from weapons.CTC_0a import ctc_recog_model

os.environ["CUDA_VISIBLE_DEVICES"] = '1'

from detecter import detecter
from recognizer import recognizer
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
detecter = detecter("models/Se_0a_1/Se_0a_1_0.ckpt")
recognizer = recognizer("models/C_0a_1/C_0a_1_0.ckpt")
# Out:
# WARNING:tensorflow:From /home/watermirror/anaconda3/envs/mingxiang_py36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/watermirror/Desktop/ccpd/weapons/Se_0a.py:73: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.batch_normalization instead.
# WARNING:tensorflow:From /home/watermirror/anaconda3/envs/mingxiang_py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# ...

# %%
path = "CCPD2019/ccpd_base/04-12_13-215&474_447&618-447&618_217&567_215&474_445&525-0_0_24_1_30_31_27-141-113.jpg"
plt.figure(figsize=(9,9))
img = cv2.imread(path)
img = np.dot(img,np.array([[0,0,1],[0,1,0],[1,0,0]]))
plt.imshow(img)
plt.show()

# %%
plate = detecter.predict([img])[0]
plt.imshow(plate)
plt.show()

# %%
num = recognizer.predict([plate])[0]
print(num)
# Out:
# 皖A0B673
